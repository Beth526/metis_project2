# %% [markdown]
# # Navigating and Scraping Spotify with Selenium for Total Monthly Listeners

# %% [markdown]
# Import the packages required and set up the chromdriver

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pickle
import numpy as np
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# First, I get a list of the artists from the top 1050 collected records dataframe I pickled

# %%
os.chdir('/Users/beth/Documents/Metis/metis_project_2/metis_project2')

# %%
with open('top_1050_collected_records.pickle', 'rb') as open_file:
    top_1050_collected_records = pickle.load(open_file)

# %% [markdown]
# A copy of the original artists name to match back to the top 1050 collected records dataframe later

# %%
top_artists_orig_names=list(top_1050_collected_records['artists'].unique())

# %% [markdown]
# A copy to edit in case I need to for spotify

# %%
top_artists=list(top_1050_collected_records['artists'].unique())

# %% [markdown]
# There are some obvious issues with the artist names, some have parentheses with numbers after them.

# %%
top_artists=list(map(lambda x: re.sub(' \([0-9]*\)','', x),top_artists))

# %% [markdown]
# Create a spotify monthly listeners list to populate

# %%
spotify_monthly_listeners=[]

# %% [markdown]
# The below will loop over all of the artists in the top_artists list, use Selenium to search for them on Spotify, and click the link to thier Spotify page, then add thier monthly listeners to the spotify_monthly_listeners list.
#
# There were issues however because of MANY artist names in discogs being slightly different than in Spotify. This is not an issue for the search step, but for the link clicking step. Selenium finds elements based on class, id, or link text, but the artist links on Spotify's search page had no class or id. Partial link text match offerered by Selenium was not useful in this case, as it led to more incorrect song or album links being clicked.
#
# There were other issues when artists had self-titled albums, with Selenium opening the album link instead of the artist link.
#
# I was not sure how to avoid these issues, and am looking into it, but in the mean time I just updated artist names in the artist list and restarted the loop at it's last position every time Selenium stalled for not finding a link.

# %%
driver.get('https://open.spotify.com/search/')

# %%
search_bar = driver.find_element_by_xpath("//input[@data-testid='search-input']")

# %%
search_bar.clear()
search_bar.send_keys("Queen")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
for link in soup.find_all('a'):
    if 'artist' in link.get('href') and 'Queen' in link.text:
        print(link)
# Out:
# <a class="f7ebc3d96230ee12a84a9b0b4b81bb8f-scss" dir="auto" draggable="false" href="/artist/1dfeR4HaWDbWqFHLkxsg1d" title="Queen"><div as="div" class="_45331a50e3963ecc26575a06f1fd5292-scss _3957b7dd066dbbba6a311b40a427c59f-scss">Queen</div></a>
# <a class="f7ebc3d96230ee12a84a9b0b4b81bb8f-scss" dir="auto" draggable="false" href="/artist/3nViOFa3kZW8OMSNOzwr98" title="Queen Naija"><div as="div" class="_45331a50e3963ecc26575a06f1fd5292-scss _3957b7dd066dbbba6a311b40a427c59f-scss">Queen Naija</div></a>
# <a class="f7ebc3d96230ee12a84a9b0b4b81bb8f-scss" dir="auto" draggable="false" href="/artist/4pejUc4iciQfgdX6OKulQn" title="Queens of the Stone Age"><div as="div" class="_45331a50e3963ecc26575a06f1fd5292-scss _3957b7dd066dbbba6a311b40a427c59f-scss">Queens of the Stone Age</div></a>
# <a class="f7ebc3d96230ee12a84a9b0b4b81bb8f-scss" dir="auto" draggable="false" href="/artist/65TI81cGOUJx4OXM4VHTND" title="Queendome Come"><div as="div" class="_45331a50e3963ecc26575a06f1fd5292-scss _3957b7dd066dbbba6a311b40a427c59f-scss">Queendome Come</div></a>
# <a dir="auto" draggable="false" href="/artist/3nViOFa3kZW8OMSNOzwr98">Queen Naija</a>

# %%
search_bar.clear()
search_bar.send_keys("")

# %%
#open the spotify search page using chromedriver
driver.get('https://open.spotify.com/search/')

#loop over all the top_artists
for i in top_artists:
    
    time.sleep(2)
    
    #locate the Spotify search bar 
    search_bar = driver.find_element_by_xpath("//input[@data-testid='search-input']")
    
    #clear the default text in the search bar
    search_bar.clear()
    
    #input the artist name in the search bar, the page updates automatically as you type
    search_bar.send_keys(i)
    
    time.sleep(2)
    
    try:
        #try to find a link containing the artist name as text
        artist_link = driver.find_element_by_link_text(i)
        
        #if the sleep here was too short the link was unclickable
        time.sleep(5)
        
        #click the link 
        artist_link.click()
        
        time.sleep(2)
        
        #collect the html for this page with beautifulsoup
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        try:
            #append the monthly listener number to the spotify_monthly_listener list, using it's class to identify it
            #regex used to find the number from this text
            spotify_monthly_listeners.append(re.search('[0-9,]*',soup.find('span', class_="_85aaee9fc23ca61102952862a10b544c-scss").text).group())
            
            time.sleep(2)
        
        except:
            #append np.nan if there is no monthly listener number (usually because the link led to a self-titled album page)
            spotify_monthy_listeners.append(np.nan)
        
        #return to the Spotify search page
        driver.back()
    
    #if the link can not be found - this causes the chrome driver to go white and alert me to update an artist name
    #so that I can restart the loop from the last position and find an artist link
    except:
    
        driver.back()
        

driver.close()

# %% [markdown]
# There were more times that I needed to update artist names than I would have like. These are all the times that I had to correct an artist name from discogs to match the Spotify spelling:

# %%
top_artists[top_artists.index('Rolling Stones')]='The Rolling Stones'

top_artists[top_artists.index('Neil Young & Crazy Horse')]='Neil Young'

top_artists[top_artists.index('Bob Seger & The Silver Bullet Band')]='Bob Seger'

top_artists[top_artists.index('Godspeed You Black Emperor!')]="Godspeed You! Black Emperor"

top_artists[top_artists.index('Simon And Garfunkel')]="Simon & Garfunkel"

top_artists[top_artists.index('The Jimi Hendrix Experience')]='Jimi Hendrix'

top_artists[360] = "CHIC"

top_artists[354] ='CAN'

top_artists[352]= "The Mamas & The Papas"

top_artists[346] ="New Order"

top_artists[344]='Daryl Hall & John Oates'

spotify_df.iloc[332,0] = "Sisters of Mercy"

top_artists[324] = "The Go-Go's"

top_artists[309] = 'John Mellencamp'

top_artists[296] = "Run-D.M.C."

top_artists[295]='M/A/R/R/S'

top_artists[288] = 'Adam & The Ants'

top_artists[278]="Boards of Canada"

top_artists[267] = "Stevie Ray Vaughan"

top_artists[247] = "The Jesus and Mary Chain"

top_artists[245] = "Steve Miller Band"

top_artists[239] = "DEVO"

top_artists[229] = "Herb Alpert & The Tijuana Brass"

top_artists[228]="Patti Smith"

top_artists[226] = "Rodgers & Hammerstein"

top_artists[223]="The Sugarhill Gang"

top_artists[222]="John Lennon"

top_artists[214] = 'Snoop Dogg'

top_artists[213] = "Bob Marley & The Wailers"

top_artists[199]="Rainbow"

top_artists[191]='Bad Company'

top_artists[190]="The Specials"

top_artists[172]="Elvis Costello & The Attractions"

top_artists[167]='Bruce Springsteen'

top_artists[162] = "The Stooges"

top_artists[157]="N.W.A."

top_artists[145]="Paul & Linda McCartney"

top_artists[141]="Neil Young"

top_artists[138]='Tom Petty and the Heartbreakers'

top_artists[134]="Jimi Hendrix"

top_artists[124]="Air"

top_artists[118]="Allman Brothers Band"

top_artists[120]='Huey Lewis & The News'

top_artists[116]="Jimi Hendrix"

top_artists[117]="Derek & The Dominos"

top_artists[90]="Jean-Michel Jarre"

top_artists[76]='David Bowie'

top_artists[12]='Prince'

# %%
spotify_df=pd.DataFrame({'top_artists_spotify_name':top_artists,'spotify_monthly_listeners':spotify_monthly_listeners})

# %% [markdown]
# After looking at the final dataframe, spotify monthly listeners was np.nan for all artists with self-titled albums, or albums by other artists with the same name. Some values were really low and this was because the another artist with the name from Discogs was accessed (like Lauryn Hill vs. Ms. Lauryn Hill).
#
# I had to manually correct these cases.

# %%
#pd.set_option('display.max_rows', 500)
#spotify_df
# Out:
#                top_artists_spotify_name spotify_monthly_listeners  \
# 0                            Pink Floyd                13,643,471
# 1                           The Beatles                22,982,890
# 2                       Michael Jackson                23,635,338
# 3                          Led Zeppelin                14,946,310
# 4                         Fleetwood Mac                18,598,676
# 5                          Dire Straits                11,271,675
# 6                           David Bowie                14,064,233
# 7                           Miles Davis                 2,003,331
# 8                                 AC/DC                19,922,477
# 9                                Eagles                14,003,141
# 10                        Black Sabbath                 8,116,712
# 11                        Guns N' Roses                18,295,010
# 12                               Prince                 9,003,826
# 13                    Bruce Springsteen                12,482,265
# 14                                   U2                15,530,369
# 15                            Radiohead                11,533,553
# 16                           Neil Young                 6,017,100
# 17                            The Doors                 8,735,607
# 18                                Queen                32,925,379
# 19                           Supertramp                 5,912,052
# 20                            The Clash                 9,008,872
# 21                            Metallica                16,070,530
# 22                    Simon & Garfunkel             (8, 839, 283)
# 23                         Jimi Hendrix                 8,497,262
# 24             Bob Marley & The Wailers                13,960,826
# 25                              The Who                 7,942,027
# 26                   The Rolling Stones                19,826,731
# 27               The Velvet Underground                 3,707,923
# 28                          Sex Pistols                 1,316,460
# 29                         Joy Division                 3,635,176
# 30                           The Police                13,790,771
# 31                         King Crimson                   759,883
# 32                          Iron Maiden                 5,866,207
# 33                    Simon & Garfunkel                 8,839,283
# 34         Crosby, Stills, Nash & Young                 2,910,090
# 35                              Various                       NaN
# 36                   The Rolling Stones                19,826,731
# 37                       The Beach Boys                 9,114,202
# 38                               Boston                 6,130,501
# 39             Rage Against The Machine                 7,017,881
# 40                        Stevie Wonder                14,108,306
# 41                          Jethro Tull                 1,548,329
# 42                              Santana                 7,821,642
# 43                            Meat Loaf                 3,036,518
# 44                          Deep Purple             (6, 173, 527)
# 45                           Elton John            (23, 907, 107)
# 46                        Mike Oldfield                 1,687,639
# 47                              Madonna                13,325,732
# 48                        Peter Gabriel                 3,812,429
# 49                              Blondie                 6,614,468
# 50                         Beastie Boys                 5,056,822
# 51                          Carole King                 3,735,827
# 52                          John Lennon                 7,589,240
# 53                              Nirvana                15,001,321
# 54                            Van Halen                 8,907,262
# 55                             The Cure                 9,786,327
# 56                           Steely Dan                 4,126,052
# 57                           The Smiths             (5, 576, 557)
# 58                             Lou Reed                 4,519,295
# 59                            Daft Punk                11,902,344
# 60                         Wu-Tang Clan                 3,903,974
# 61               John Lennon & Yoko Ono                       153
# 62                               ZZ Top                 6,186,575
# 63                         Depeche Mode                 7,943,902
# 64                                Wings                 4,038,542
# 65                            Bob Dylan                 9,246,991
# 66                      Tears For Fears                 8,519,639
# 67                         Phil Collins                14,145,721
# 68                        Talking Heads                 5,916,526
# 69                           Billy Joel                14,462,184
# 70                                 Sade                 3,874,788
# 71             Electric Light Orchestra                 9,223,079
# 72                            New Order                 5,454,386
# 73             The Dave Brubeck Quartet                 1,237,571
# 74                          Marvin Gaye                12,048,634
# 75         Creedence Clearwater Revival                13,730,629
# 76                          David Bowie                14,064,233
# 77                  Yusef / Cat Stevens             (6, 719, 900)
# 78                        John Coltrane                 2,163,786
# 79                                  Yes                 2,601,318
# 80                          Men At Work                 4,903,759
# 81                         Eric Clapton                10,454,135
# 82                             The Cars             (4, 567, 427)
# 83                       Peter Frampton                 1,912,510
# 84                            Kraftwerk                   930,902
# 85                         Janis Joplin                 4,005,604
# 86                       Iron Butterfly                   360,345
# 87                        Tracy Chapman             (7, 351, 870)
# 88                               Prince                 9,003,826
# 89                                  Nas                 7,345,246
# 90                    Jean-Michel Jarre                   541,385
# 91                          Johnny Cash             (9, 691, 840)
# 92                                Cream                 4,661,709
# 93                                 Rush                 3,653,270
# 94                             Bon Jovi                16,646,882
# 95                               Pixies                 4,761,180
# 96                              Genesis                 4,918,032
# 97                       Massive Attack                 2,874,616
# 98                                 TOTO            (12, 537, 464)
# 99                Crosby, Stills & Nash                 2,458,703
# 100                               Sting                 7,024,343
# 101                         Duran Duran                 5,957,905
# 102                         Def Leppard                 5,061,056
# 103                       Lionel Richie                 8,244,471
# 104                                INXS                 5,131,104
# 105                           Aerosmith                15,082,896
# 106                     George Harrison                 5,612,427
# 107                          Roxy Music                 2,411,097
# 108                           Foreigner                 7,267,125
# 109                        Van Morrison                 9,459,108
# 110                                KISS             (8, 632, 236)
# 111                      Kendrick Lamar                25,732,149
# 112                             Ramones                 3,764,966
# 113                     The Stone Roses                 1,929,349
# 114                   The White Stripes                 7,989,351
# 115            The Alan Parsons Project                 2,606,926
# 116                        Jimi Hendrix                 8,497,262
# 117                 Derek & The Dominos                 3,010,439
# 118                Allman Brothers Band                 3,916,885
# 119                         Blind Faith                (488, 620)
# 120               Huey Lewis & The News                 4,577,135
# 121                           Kate Bush                 2,498,633
# 122                          The B-52's                 2,692,535
# 123                     The Moody Blues                 1,878,968
# 124                                 Air                 1,739,838
# 125                       Ozzy Osbourne                 7,099,205
# 126                      Arctic Monkeys                14,252,290
# 127                                ABBA                12,461,114
# 128                         Bryan Adams                13,989,357
# 129                           Stan Getz                 2,692,339
# 130                              Fugees                 5,265,751
# 131                      George Michael                10,469,338
# 132           Frankie Goes To Hollywood                 2,177,425
# 133                  Jefferson Airplane                 2,874,430
# 134                        Jimi Hendrix                 8,497,262
# 135                           DJ Shadow                 2,072,862
# 136                        Cyndi Lauper                 9,172,668
# 137                         Tina Turner                12,832,740
# 138     Tom Petty and the Heartbreakers                 6,032,835
# 139                   Steve Miller Band                 5,973,572
# 140                              Slayer                 1,922,565
# 141                          Neil Young                 6,017,100
# 142                        Lana Del Rey                17,100,857
# 143                             Dr. Dre                11,780,379
# 144                         The Stooges                 1,032,915
# 145              Paul & Linda McCartney                        16
# 146                        Judas Priest                 3,243,319
# 147                          Whitesnake                 5,332,558
# 148                     Nine Inch Nails                 2,806,437
# 149                      Jackson Browne                 3,431,310
# 150                              T. Rex                 3,097,399
# 151                       Dead Kennedys                 1,092,788
# 152                  The Blues Brothers                   827,579
# 153   Big Brother & The Holding Company                 1,641,221
# 154                             Prodigy                   174,432
# 155                   Simon & Garfunkel                 8,839,283
# 156                       John Williams                 4,339,430
# 157                              N.W.A.                 4,253,509
# 158                                a-ha                 9,601,308
# 159                       Leonard Cohen                 3,222,994
# 160                          Jack White                 1,188,301
# 161                      Herbie Hancock                 1,724,769
# 162                         The Stooges                 1,032,915
# 163                         Patti Smith                 2,298,029
# 164                             Journey                12,156,773
# 165                      Elvis Costello             (1, 690, 573)
# 166                       Joni Mitchell                 3,942,636
# 167                   Bruce Springsteen                12,482,265
# 168                               Wham!                 7,683,690
# 169                           Pearl Jam                 9,974,899
# 170                        Stevie Nicks                 3,795,012
# 171                          Television                (661, 405)
# 172    Elvis Costello & The Attractions                 1,194,347
# 173                        Culture Club                 4,086,101
# 174                     Whitney Houston            (20, 254, 501)
# 175                                Asia                 1,138,589
# 176                    The Human League                 3,279,608
# 177                          Neil Young                 6,017,100
# 178                      Paul McCartney             (9, 221, 287)
# 179                          Don McLean                 5,075,759
# 180                          Pretenders             (4, 351, 729)
# 181                           Motörhead                 3,772,643
# 182              Emerson, Lake & Palmer                   700,107
# 183                         Arcade Fire                 4,203,976
# 184                             Madness             (2, 602, 586)
# 185                          Jeff Wayne                   159,727
# 186                               Heart                 5,907,066
# 187                         Frank Zappa                 1,059,301
# 188                                 Dio                 2,044,190
# 189                             America                 5,673,471
# 190                        The Specials                 1,212,032
# 191                         Bad Company                 2,625,644
# 192                         Fleet Foxes                 3,515,515
# 193                  Traveling Wilburys                 1,337,201
# 194                          Billy Idol                 5,985,258
# 195                            The Band                 3,546,520
# 196                      Lynyrd Skynyrd                10,821,025
# 197                       Grateful Dead                 2,979,305
# 198                       Pet Shop Boys                 4,652,540
# 199                             Rainbow                 1,951,319
# 200                         Cheap Trick                 4,183,567
# 201                Terence Trent D'Arby                   952,038
# 202                              R.E.M.                10,647,809
# 203                 The Doobie Brothers                 6,240,896
# 204                         Rod Stewart                 8,651,435
# 205                           Scorpions                 8,735,183
# 206                                Doom                    48,533
# 207                        Simple Minds                 6,249,137
# 208                            Megadeth                 3,079,767
# 209                     Curtis Mayfield                 2,608,790
# 210                            Iggy Pop                 3,998,378
# 211                          De La Soul                 1,165,731
# 212                                Love                 1,185,978
# 213            Bob Marley & The Wailers            (13, 960, 826)
# 214                          Snoop Dogg                20,094,615
# 215                                Styx                 3,452,516
# 216                      Gerry Rafferty                 2,051,282
# 217                         Mötley Crüe                 5,371,425
# 218                              Europe                 5,031,892
# 219                      REO Speedwagon                 4,384,071
# 220                        Alice Cooper                 3,906,544
# 221                           Marillion                 1,111,162
# 222                         John Lennon                 7,589,240
# 223                  The Sugarhill Gang                 1,255,218
# 224                            Gorillaz            (11, 545, 469)
# 225                               Wings                 4,038,542
# 226               Rodgers & Hammerstein                     2,195
# 227                          Eurythmics                 7,591,268
# 228                         Patti Smith                 2,298,029
# 229     Herb Alpert & The Tijuana Brass                   638,256
# 230                          Thin Lizzy                 3,889,912
# 231                        Public Enemy                 1,891,981
# 232                          Paul Simon                 7,006,906
# 233                   Christopher Cross             (3, 335, 836)
# 234                            Bee Gees                11,380,354
# 235                          Nick Drake                 2,029,284
# 236                            Bon Iver                 7,087,412
# 237                      Violent Femmes                 1,536,704
# 238                        Donald Fagen                   356,641
# 239                                DEVO                 1,418,181
# 240                           Bob Seger                 4,572,113
# 241                              Kansas                 6,485,624
# 242                A Tribe Called Quest                 3,760,588
# 243                         Sonic Youth                 1,618,830
# 244                             Chicago                 6,398,167
# 245                   Steve Miller Band                 5,973,572
# 246                       Grateful Dead             (2, 979, 305)
# 247            The Jesus and Mary Chain                   887,942
# 248                       Faith No More                 3,083,300
# 249                  Earth, Wind & Fire                11,935,709
# 250                          Al Stewart                   952,691
# 251       The Rocky Horror Picture Show                       NaN
# 252                           Tom Waits                 1,628,512
# 253                            Boney M.                 4,446,480
# 254                         Joe Jackson                 1,159,936
# 255                          Carpenters             (3, 253, 977)
# 256                     Ms. Lauryn Hill                 4,470,005
# 257                               Adele                22,798,628
# 258                         John Denver                 6,948,285
# 259                      Paul McCartney                 9,221,287
# 260                               Yazoo                 1,604,239
# 261                         Pat Benatar                 3,019,624
# 262                        James Taylor                 5,099,436
# 263                           Soft Cell                 3,942,808
# 264                       The Offspring             (9, 120, 871)
# 265           Chicago Transit Authority                  (1, 178)
# 266                           The Knack                 2,297,152
# 267                  Stevie Ray Vaughan                 2,167,991
# 268                        The National                 2,621,554
# 269                       Keith Jarrett                   829,896
# 270                           Tom Petty                 7,577,953
# 271                          Simply Red                 4,690,844
# 272                      Twisted Sister                 3,405,906
# 273                          Funkadelic                 1,276,020
# 274                            Interpol                 2,200,034
# 275                    The War On Drugs                 1,525,460
# 276                                 ELO                    88,875
# 277                         The Wailers                 2,410,858
# 278                    Boards of Canada                   729,269
# 279              Blood, Sweat And Tears                (335, 440)
# 280                     John Mellencamp             (4, 553, 261)
# 281                           Brian Eno                 1,659,821
# 282                            The Cult                 1,610,631
# 283                    Blue Öyster Cult                 4,342,759
# 284                        Midnight Oil                 1,925,654
# 285                        Jimi Hendrix                 8,497,262
# 286                             Rainbow                 1,951,319
# 287                 Cannonball Adderley                   539,142
# 288                     Adam & The Ants                   257,333
# 289                         The Mothers                   129,443
# 290                         Isaac Hayes                 1,140,300
# 291                      Sufjan Stevens                 6,235,979
# 292                             J Dilla                   869,233
# 293         Godspeed You! Black Emperor                   168,089
# 294                          Boz Scaggs                 1,844,275
# 295                           M/A/R/R/S                   149,183
# 296                          Run-D.M.C.             (3, 622, 251)
# 297                      Weather Report                   265,174
# 298                        Suzanne Vega             (1, 168, 528)
# 299                          Quiet Riot                 2,593,828
# 300                          Uriah Heep                   733,444
# 301                         Grace Jones                 1,249,184
# 302                          Pretenders             (4, 351, 729)
# 303         Joan Jett & The Blackhearts                 3,684,395
# 304              Sly & The Family Stone                 2,619,862
# 305                               alt-J                 6,359,213
# 306                           Talk Talk                 2,054,788
# 307                         Bing Crosby                 1,242,491
# 308                               Ghost                 1,650,557
# 309                     John Mellencamp                 4,553,261
# 310                           Morrissey                 1,797,400
# 311   Orchestral Manoeuvres In The Dark             (2, 280, 677)
# 312                    Barbra Streisand                 3,869,047
# 313                   Leonard Bernstein                 1,143,631
# 314                      Vince Guaraldi                   109,774
# 315                        Neil Diamond                 5,772,111
# 316                       Willie Nelson                 4,926,120
# 317                                 MC5                   201,282
# 318                           Jim Croce                 2,784,107
# 319                            Stardust                 1,146,229
# 320                     Paul Hardcastle                   310,955
# 321                                 ABC                (831, 864)
# 322                           Jeff Beck                   841,790
# 323                           J.J. Cale                 1,507,533
# 324                         The Go-Go's                   961,104
# 325                         Tame Impala                13,494,403
# 326                         Bad Company                 2,625,644
# 327                   The J. Geils Band                 2,147,736
# 328                               Wilco                 2,171,015
# 329                         The Strokes                 7,266,885
# 330                         John Mayall                   192,327
# 331                      Spandau Ballet                 3,659,120
# 332                    Sisters of Mercy                (491, 796)
# 333  Captain Beefheart & His Magic Band                   441,009
# 334                       Elvis Presley            (12, 379, 977)
# 335                            Band Aid                   400,424
# 336                            Ultravox                 1,020,287
# 337                             Traffic                   709,492
# 338                       David Gilmour                 1,002,086
# 339                          Audioslave             (5, 235, 964)
# 340                        Alice Cooper                 3,906,544
# 341                        Cypress Hill                 3,725,896
# 342                             Anthrax                 1,184,872
# 343                      Charles Mingus                   618,078
# 344             Daryl Hall & John Oates                10,319,889
# 345                          Alphaville                 4,000,736
# 346                           New Order                 5,454,386
# 347                                Muse             (8, 890, 515)
# 348                                Blur                 6,441,748
# 349                          Gary Numan                   874,537
# 350                               Bread             (2, 723, 145)
# 351               Red Hot Chili Peppers                19,650,812
# 352               The Mamas & The Papas                 4,733,152
# 353                         The Zombies                 2,159,111
# 354                                 CAN                (689, 779)
# 355                            Vangelis                 1,320,173
# 356                      Ray Parker Jr.                 1,479,651
# 357                          Lil' Louis                 (72, 174)
# 358               The Chemical Brothers                 2,723,790
# 359                         The Monkees                 3,940,062
# 360                                CHIC                 3,004,752
# 361                                 Eno                 1,138,921
# 362                Fine Young Cannibals                 2,248,877
#
#                      top_artists_orig_name
# 0                               Pink Floyd
# 1                              The Beatles
# 2                          Michael Jackson
# 3                             Led Zeppelin
# 4                            Fleetwood Mac
# 5                             Dire Straits
# 6                              David Bowie
# 7                              Miles Davis
# 8                                    AC/DC
# 9                                   Eagles
# 10                           Black Sabbath
# 11                           Guns N' Roses
# 12               Prince And The Revolution
# 13                       Bruce Springsteen
# 14                                      U2
# 15                               Radiohead
# 16                              Neil Young
# 17                               The Doors
# 18                                   Queen
# 19                              Supertramp
# 20                               The Clash
# 21                               Metallica
# 22                     Simon and Garfunkel
# 23             The Jimi Hendrix Experience
# 24                Bob Marley & The Wailers
# 25                                 The Who
# 26                      The Rolling Stones
# 27                  The Velvet Underground
# 28                             Sex Pistols
# 29                            Joy Division
# 30                              The Police
# 31                            King Crimson
# 32                             Iron Maiden
# 33                       Simon & Garfunkel
# 34            Crosby, Stills, Nash & Young
# 35                                 Various
# 36                          Rolling Stones
# 37                          The Beach Boys
# 38                                  Boston
# 39                Rage Against The Machine
# 40                           Stevie Wonder
# 41                             Jethro Tull
# 42                                 Santana
# 43                               Meat Loaf
# 44                             Deep Purple
# 45                              Elton John
# 46                           Mike Oldfield
# 47                                 Madonna
# 48                           Peter Gabriel
# 49                                 Blondie
# 50                            Beastie Boys
# 51                             Carole King
# 52                             John Lennon
# 53                                 Nirvana
# 54                               Van Halen
# 55                                The Cure
# 56                              Steely Dan
# 57                              The Smiths
# 58                                Lou Reed
# 59                               Daft Punk
# 60                            Wu-Tang Clan
# 61                  John Lennon & Yoko Ono
# 62                                  ZZ Top
# 63                            Depeche Mode
# 64                Paul McCartney And Wings
# 65                               Bob Dylan
# 66                         Tears For Fears
# 67                            Phil Collins
# 68                           Talking Heads
# 69                              Billy Joel
# 70                                    Sade
# 71                Electric Light Orchestra
# 72                               New Order
# 73                The Dave Brubeck Quartet
# 74                             Marvin Gaye
# 75            Creedence Clearwater Revival
# 76                                   Bowie
# 77                             Cat Stevens
# 78                           John Coltrane
# 79                                     Yes
# 80                             Men At Work
# 81                            Eric Clapton
# 82                                The Cars
# 83                          Peter Frampton
# 84                               Kraftwerk
# 85                            Janis Joplin
# 86                          Iron Butterfly
# 87                           Tracy Chapman
# 88                                  Prince
# 89                                     Nas
# 90                       Jean Michel Jarre
# 91                             Johnny Cash
# 92                                   Cream
# 93                                    Rush
# 94                                Bon Jovi
# 95                                  Pixies
# 96                                 Genesis
# 97                          Massive Attack
# 98                                    Toto
# 99                   Crosby, Stills & Nash
# 100                                  Sting
# 101                            Duran Duran
# 102                            Def Leppard
# 103                          Lionel Richie
# 104                                   INXS
# 105                              Aerosmith
# 106                        George Harrison
# 107                             Roxy Music
# 108                              Foreigner
# 109                           Van Morrison
# 110                                   Kiss
# 111                         Kendrick Lamar
# 112                                Ramones
# 113                        The Stone Roses
# 114                      The White Stripes
# 115               The Alan Parsons Project
# 116                                Hendrix
# 117                  Derek And The Dominos
# 118               The Allman Brothers Band
# 119                            Blind Faith
# 120                Huey Lewis And The News
# 121                              Kate Bush
# 122                             The B-52's
# 123                        The Moody Blues
# 124                        AIR French Band
# 125                          Ozzy Osbourne
# 126                         Arctic Monkeys
# 127                                   ABBA
# 128                            Bryan Adams
# 129                              Stan Getz
# 130                                 Fugees
# 131                         George Michael
# 132              Frankie Goes To Hollywood
# 133                     Jefferson Airplane
# 134                Jimi Hendrix Experience
# 135                              DJ Shadow
# 136                           Cyndi Lauper
# 137                            Tina Turner
# 138        Tom Petty And The Heartbreakers
# 139                      Steve Miller Band
# 140                                 Slayer
# 141            Neil Young With Crazy Horse
# 142                           Lana Del Rey
# 143                                Dr. Dre
# 144                            The Stooges
# 145               Paul And Linda McCartney
# 146                           Judas Priest
# 147                             Whitesnake
# 148                        Nine Inch Nails
# 149                         Jackson Browne
# 150                                 T. Rex
# 151                          Dead Kennedys
# 152                     The Blues Brothers
# 153      Big Brother & The Holding Company
# 154                                Prodigy
# 155                    Simon And Garfunkel
# 156                          John Williams
# 157                                  N.W.A
# 158                                   a-ha
# 159                          Leonard Cohen
# 160                             Jack White
# 161                         Herbie Hancock
# 162                   Iggy And The Stooges
# 163                            Patti Smith
# 164                                Journey
# 165                         Elvis Costello
# 166                          Joni Mitchell
# 167  Bruce Springsteen & The E Street Band
# 168                                  Wham!
# 169                              Pearl Jam
# 170                           Stevie Nicks
# 171                             Television
# 172     Elvis Costello And The Attractions
# 173                           Culture Club
# 174                        Whitney Houston
# 175                                   Asia
# 176                       The Human League
# 177               Neil Young & Crazy Horse
# 178                              McCartney
# 179                             Don McLean
# 180                             Pretenders
# 181                              Motörhead
# 182                 Emerson, Lake & Palmer
# 183                            Arcade Fire
# 184                                Madness
# 185                             Jeff Wayne
# 186                                  Heart
# 187                            Frank Zappa
# 188                                    Dio
# 189                                America
# 190                               Specials
# 191                                 Bad Co
# 192                            Fleet Foxes
# 193                     Traveling Wilburys
# 194                             Billy Idol
# 195                               The Band
# 196                         Lynyrd Skynyrd
# 197                          Grateful Dead
# 198                          Pet Shop Boys
# 199                    Blackmore's Rainbow
# 200                            Cheap Trick
# 201                   Terence Trent D'Arby
# 202                                 R.E.M.
# 203                    The Doobie Brothers
# 204                            Rod Stewart
# 205                              Scorpions
# 206                                   Doom
# 207                           Simple Minds
# 208                               Megadeth
# 209                        Curtis Mayfield
# 210                               Iggy Pop
# 211                             De La Soul
# 212                                   Love
# 213             Bob Marley And The Wailers
# 214                       Snoop Doggy Dogg
# 215                                   Styx
# 216                         Gerry Rafferty
# 217                            Mötley Crüe
# 218                                 Europe
# 219                         REO Speedwagon
# 220                           Alice Cooper
# 221                              Marillion
# 222                                 Lennon
# 223                         Sugarhill Gang
# 224                               Gorillaz
# 225                                  Wings
# 226                Rodgers And Hammerstein
# 227                             Eurythmics
# 228                      Patti Smith Group
# 229            Herb Alpert's Tijuana Brass
# 230                             Thin Lizzy
# 231                           Public Enemy
# 232                             Paul Simon
# 233                      Christopher Cross
# 234                               Bee Gees
# 235                             Nick Drake
# 236                               Bon Iver
# 237                         Violent Femmes
# 238                           Donald Fagen
# 239                                   Devo
# 240     Bob Seger & The Silver Bullet Band
# 241                                 Kansas
# 242                   A Tribe Called Quest
# 243                            Sonic Youth
# 244                                Chicago
# 245                  The Steve Miller Band
# 246                      The Grateful Dead
# 247               The Jesus And Mary Chain
# 248                          Faith No More
# 249                     Earth, Wind & Fire
# 250                             Al Stewart
# 251          The Rocky Horror Picture Show
# 252                              Tom Waits
# 253                               Boney M.
# 254                            Joe Jackson
# 255                             Carpenters
# 256                            Lauryn Hill
# 257                                  Adele
# 258                            John Denver
# 259                         Paul McCartney
# 260                                  Yazoo
# 261                            Pat Benatar
# 262                           James Taylor
# 263                              Soft Cell
# 264                              Offspring
# 265              Chicago Transit Authority
# 266                              The Knack
# 267  Stevie Ray Vaughan And Double Trouble
# 268                           The National
# 269                          Keith Jarrett
# 270                              Tom Petty
# 271                             Simply Red
# 272                         Twisted Sister
# 273                             Funkadelic
# 274                               Interpol
# 275                       The War On Drugs
# 276                                    ELO
# 277                            The Wailers
# 278                       Boards Of Canada
# 279                 Blood, Sweat And Tears
# 280                            John Cougar
# 281                              Brian Eno
# 282                               The Cult
# 283                       Blue Öyster Cult
# 284                           Midnight Oil
# 285                           Jimi Hendrix
# 286                                Rainbow
# 287                    Cannonball Adderley
# 288                      Adam And The Ants
# 289                            The Mothers
# 290                            Isaac Hayes
# 291                         Sufjan Stevens
# 292                                J Dilla
# 293            Godspeed You Black Emperor!
# 294                             Boz Scaggs
# 295                              M|A|R|R|S
# 296                                Run DMC
# 297                         Weather Report
# 298                           Suzanne Vega
# 299                             Quiet Riot
# 300                             Uriah Heep
# 301                            Grace Jones
# 302                         The Pretenders
# 303            Joan Jett & The Blackhearts
# 304                 Sly & The Family Stone
# 305                                  alt-J
# 306                              Talk Talk
# 307                            Bing Crosby
# 308                                  Ghost
# 309                 John Cougar Mellencamp
# 310                              Morrissey
# 311      Orchestral Manoeuvres In The Dark
# 312                       Barbra Streisand
# 313                      Leonard Bernstein
# 314                         Vince Guaraldi
# 315                           Neil Diamond
# 316                          Willie Nelson
# 317                                    MC5
# 318                              Jim Croce
# 319                               Stardust
# 320                        Paul Hardcastle
# 321                                    ABC
# 322                              Jeff Beck
# 323                              J.J. Cale
# 324                                Go-Go's
# 325                            Tame Impala
# 326                            Bad Company
# 327                      The J. Geils Band
# 328                                  Wilco
# 329                            The Strokes
# 330                            John Mayall
# 331                         Spandau Ballet
# 332                   The Sisters Of Mercy
# 333     Captain Beefheart & His Magic Band
# 334                          Elvis Presley
# 335                               Band Aid
# 336                               Ultravox
# 337                                Traffic
# 338                          David Gilmour
# 339                             Audioslave
# 340                           Alice Cooper
# 341                           Cypress Hill
# 342                                Anthrax
# 343                         Charles Mingus
# 344                  Daryl Hall John Oates
# 345                             Alphaville
# 346                               Neworder
# 347                                   Muse
# 348                                   Blur
# 349                             Gary Numan
# 350                                  Bread
# 351                  Red Hot Chili Peppers
# 352              The Mama's And The Papa's
# 353                            The Zombies
# 354                                    Can
# 355                               Vangelis
# 356                         Ray Parker Jr.
# 357                              Lil Louis
# 358                  The Chemical Brothers
# 359                            The Monkees
# 360                                   Chic
# 361                                    Eno
# 362                   Fine Young Cannibals

# %%
spotify_df.iloc[357,1] = '72,174'

spotify_df.iloc[357,0] = "Lil' Louis"

spotify_df.iloc[354,1] = '689,779'

spotify_df.iloc[350,1] = '2,723,145'

spotify_df.iloc[347,1] = '8,890,515'

spotify_df.iloc[339,1] = '5,235,964'

spotify_df.iloc[338,1] ='1,002,086'

spotify_df.iloc[334,1] = '12,379,977'

spotify_df.iloc[332,1] = '491,796'

spotify_df.iloc[332,0] = "Sisters of Mercy"

spotify_df.iloc[321,1] = '831,864'

spotify_df.iloc[311,1] = '2,280,677'

spotify_df.iloc[302,1] = '4,351,729'

spotify_df.iloc[302,0] = "Pretenders"

spotify_df.iloc[298,1] = '1,168,528'

spotify_df.iloc[296,1] = '3,622,251'

spotify_df.iloc[280,1] = '4,553,261'

spotify_df.iloc[280,0] = "John Mellencamp"

spotify_df.iloc[279,1] = '335,440'

spotify_df.iloc[265,1] = '1,178'

spotify_df.iloc[265,0] = "Chicago Transit Authority"

spotify_df.iloc[264,1] = '9,120,871'

spotify_df.iloc[264,0] = "The Offspring"

spotify_df.iloc[256,1] = '4,470,005'

spotify_df.iloc[256,0] = "Ms. Lauryn Hill"

spotify_df.iloc[255,1] = '3,253,977'

spotify_df.iloc[246,1] = '2,979,305'

spotify_df.iloc[246,0] = "Grateful Dead"

spotify_df.iloc[233,1] = '3,335,836'

spotify_df.iloc[232,1] ='7,006,906'

spotify_df.iloc[224,1] = '11,545,469'

spotify_df.iloc[213,1] = '13,960,826'

spotify_df.iloc[184,1] = '2,602,586'

spotify_df.iloc[180,1] = '4,351,729'

spotify_df.iloc[178,1] = '9,221,287'

spotify_df.iloc[178,0] = 'Paul McCartney'

spotify_df.iloc[174,1] = '20,254,501'

spotify_df.iloc[171,1] = '661,405'

spotify_df.iloc[165,1] = '1,690,573'

spotify_df.iloc[119,1] = '488,620'

spotify_df.iloc[110,1] = '8,632,236'

spotify_df.iloc[110,0] = "KISS"

spotify_df.iloc[105,1] = '15,082,896'

spotify_df.iloc[98,1] = '12,537,464'

spotify_df.iloc[98,0] = "TOTO"

spotify_df.iloc[96,1] = '4,918,032'

spotify_df.iloc[91,1] = '9,691,840'

spotify_df.iloc[87,1] = '7,351,870'

spotify_df.iloc[82,1] = '4,567,427'

spotify_df.iloc[22,0] = "Simon & Garfunkel"

spotify_df.iloc[22,1] = '8,839,283'

spotify_df.iloc[45,1] = '23,907,107'

spotify_df.iloc[57,1] = '5,576,557'

spotify_df.iloc[64,0] = "Wings"

spotify_df.iloc[64,1] = '40,38542'

spotify_df.iloc[77,0] = 'Yusef / Cat Stevens'

spotify_df.iloc[77,1] = '6,719,900'

spotify_df.iloc[265,0] = "Chicago"
spotify_df.iloc[265,1] = '6,398,167'

spotify_df.iloc[145,0] = "Paul McCartney"
spotify_df.iloc[145,1] = '9,221,287'

spotify_df.iloc[61,0] = "John Lennon"
spotify_df.iloc[61,1] = '7,589,240'

# %%
spotify_df['spotify_monthly_listeners'] = spotify_df['spotify_monthly_listeners'].str.replace(',','')

# %%
spotify_df['spotify_monthly_listeners'] = spotify_df['spotify_monthly_listeners'].astype('int')

# %%
with open('spotify_df_final.pickle', 'wb') as write_file:
    pickle.dump(spotify_df, write_file)
